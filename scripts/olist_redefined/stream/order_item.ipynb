# %% [markdown]
# 하나의 주문에 여러 아이템이 있을 수 있음

# %%
import pandas as pd
import os
import numpy as np
from datetime import timedelta

# %%
from pathlib import Path

REDEFINED_DIR = "../../../downloads/olist_redefined"
STREAM_DST = Path(os.path.join(REDEFINED_DIR, 'stream'))
CDC_DST = Path(os.path.join(REDEFINED_DIR, 'cdc'))
os.makedirs(STREAM_DST, exist_ok=True)
os.makedirs(CDC_DST, exist_ok=True)

# %%
order_items = pd.read_csv("../../../downloads/olist/olist_order_items_dataset.csv")
order_items.drop_duplicates().sort_values(['order_id', 'order_item_id']) \
    .to_csv(f"{STREAM_DST}/order_item.tsv", index=False, sep='\t')
