# %% [markdown]
# - 로그에 누락이 있을 수 있음
# - 분할 결제가 있을 수 있음
# - 분할 결제의 경우, 결제 완료 시간에서 payment_sequential의 내림차순으로 20~40초 사이의 임의의 시간만큼 차감

# %%
import pandas as pd
import os
import numpy as np
from datetime import timedelta

# %%
REDEFINED_DIR = "../../../downloads/olist_redefined"
STREAM_DST = os.path.join(REDEFINED_DIR, 'stream')
BATCH_DST = os.path.join(REDEFINED_DIR, 'batch')
os.makedirs(STREAM_DST, exist_ok=True)
os.makedirs(BATCH_DST, exist_ok=True)

# %%
orders = pd.read_csv("../../../downloads/olist/olist_orders_dataset.csv")

melted_orders = pd.melt(
    orders,
    id_vars=['order_id', 'customer_id', 'order_status'],  # 고정할 컬럼
    value_vars=['order_purchase_timestamp', 'order_approved_at', 
                'order_delivered_carrier_date', 'order_delivered_customer_date', 
                ],  # 변환할 컬럼
    var_name='current_status',  # 'timestamp'는 값의 유형이 아니라 컬럼의 유형을 나타내므로 'timestamp_type'으로 변경 추천
    value_name='timestamp'  # 값이 타임스탬프이므로 'timestamp'로 설정
).dropna().sort_values('timestamp')

melted_orders.rename(columns={'order_status': "final_status"}, inplace=True)
melted_orders['current_status'] = melted_orders['current_status'].apply(lambda x: "_".join(x.split("_")[1:-1]))
melted_orders['current_status'] = melted_orders['current_status'].apply(lambda x: "delivered" if x == "delivered_customer" else x)

# %%
orders_stream = melted_orders[['timestamp', 'order_id', 'customer_id', 'current_status']]
orders_stream = orders_stream.sort_values(['order_id', 'timestamp'])
orders_stream
# Out:
#                   timestamp                          order_id  \
# 85267   2017-09-13 08:59:02  00010242fe8c5a6d1ba2dd792cb16214
# 184708  2017-09-13 09:45:35  00010242fe8c5a6d1ba2dd792cb16214
# 284149  2017-09-19 18:34:16  00010242fe8c5a6d1ba2dd792cb16214
# 383590  2017-09-20 23:43:48  00010242fe8c5a6d1ba2dd792cb16214
# 71853   2017-04-26 10:53:06  00018f77f2f0320c557190d7a144bdd3
# ...                     ...                               ...
# 358194  2017-08-16 21:59:40  fffe18544ffabc95dfada21779c9644f
# 59741   2018-06-09 17:00:18  fffe41c64501cc87c801fd61db3f6244
# 159182  2018-06-09 17:10:13  fffe41c64501cc87c801fd61db3f6244
# 258623  2018-06-11 14:11:00  fffe41c64501cc87c801fd61db3f6244
# 358064  2018-06-14 17:56:26  fffe41c64501cc87c801fd61db3f6244
#
#                              customer_id     current_status
# 85267   3ce436f183e68e07877b285a838db11a           purchase
# 184708  3ce436f183e68e07877b285a838db11a           approved
# 284149  3ce436f183e68e07877b285a838db11a  delivered_carrier
# 383590  3ce436f183e68e07877b285a838db11a          delivered
# 71853   f6dd3ec061db4e3987629fe6b26e5cce           purchase
# ...                                  ...                ...
# 358194  b5e6afd5a41800fdf401e0272ca74655          delivered
# 59741   96d649da0cc4ff33bb408b199d4c7dcf           purchase
# 159182  96d649da0cc4ff33bb408b199d4c7dcf           approved
# 258623  96d649da0cc4ff33bb408b199d4c7dcf  delivered_carrier
# 358064  96d649da0cc4ff33bb408b199d4c7dcf          delivered
#
# [392856 rows x 4 columns]

# %%
purchase = orders_stream[orders_stream['current_status'] == 'purchase'].drop(columns='current_status')
purchase = purchase.sort_values('timestamp')
purchase
# Out:
#                  timestamp                          order_id  \
# 4541   2016-09-04 21:15:19  2e7a8482f6fb09756ca50c10d7bfc047
# 4396   2016-09-05 00:15:34  e5fa5a7210941f7d56d0208e4e071d35
# 10071  2016-09-13 15:24:19  809a282bbd5dbcabb6f2f724fca862ec
# 30710  2016-09-15 12:16:38  bfbd0f9bdef84302105ad712db648a6c
# 83078  2016-10-02 22:07:52  71303d7e93b399f5bcd537d124c0bcfa
# ...                    ...                               ...
# 50387  2018-09-29 09:13:03  392ed9afd714e3c74767d0c4d3e3f477
# 88500  2018-10-01 15:30:09  616fa7d4871b87832197b2a137a115d2
# 31891  2018-10-03 18:55:29  a2ac6dad85cf8af5b0afb510a240fe8c
# 68373  2018-10-16 20:16:02  b059ee4de278302d550a3035c4cdb740
# 60938  2018-10-17 17:30:18  10a045cdf6a5650c21e9cfeb60384c16
#
#                             customer_id
# 4541   08c5351a6aca1c1589a38f244edeee9d
# 4396   683c54fc24d40ee9f8a6fc179fd9856c
# 10071  622e13439d6b5a0b486c435618b2679e
# 30710  86dc2ffce2dfff336de2f386a786e574
# 83078  b106b360fe2ef8849fbbd056f777b4d5
# ...                                 ...
# 50387  2823ffda607a2316375088e0d00005ec
# 88500  bf6181a85bbb4115736c0a8db1a53be3
# 31891  4c2ec60c29d10c34bd49cb88aa85cfc4
# 68373  856336203359aa6a61bf3826f7d84c49
# 60938  a4b417188addbc05b26b72d5e44837a1
#
# [99441 rows x 3 columns]

# %%
payments = pd.read_csv("../../../downloads/olist/olist_order_payments_dataset.csv")
payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 0                          8          99.33
# 1                          1          24.39
# 2                          1          65.71
# 3                          8         107.78
# 4                          2         128.45
# ...                      ...            ...
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58
#
# [103886 rows x 5 columns]

# %%
payment_log = pd.merge(payments, purchase, on='order_id', how='outer')

from pathlib import Path
customers = pd.read_csv(Path(BATCH_DST) / 'customers.tsv', sep='\t')
customer_ids = customers.drop(columns='zip_code')
payment_log = pd.merge(payment_log, customer_ids, on='customer_id', how='left')
payment_log.drop(columns='customer_id', inplace=True)
payment_log.rename(columns={"customer_unique_id": 'customer_id'}, inplace=True)

payment_log = payment_log[
    ['timestamp', 'order_id', 'customer_id', 'payment_sequential', 'payment_type',
       'payment_installments', 'payment_value']].sort_values(['timestamp', 'order_id', 'payment_sequential'])
payment_log.head()
# Out:
#                  timestamp                          order_id  \
# 18789  2016-09-04 21:15:19  2e7a8482f6fb09756ca50c10d7bfc047
# 93479  2016-09-05 00:15:34  e5fa5a7210941f7d56d0208e4e071d35
# 52193  2016-09-13 15:24:19  809a282bbd5dbcabb6f2f724fca862ec
# 77762  2016-09-15 12:16:38  bfbd0f9bdef84302105ad712db648a6c
# 46099  2016-10-02 22:07:52  71303d7e93b399f5bcd537d124c0bcfa
#
#                             customer_id  payment_sequential payment_type  \
# 18789  b7d76e111c89f7ebf14761390f0f7d17                 1.0  credit_card
# 93479  4854e9b3feff728c13ee5fc7d1547e92                 1.0  credit_card
# 52193  009b0127b727ab0ba422f6d9604487c7                 1.0  credit_card
# 77762  830d5b7aaa3b6f1e9ad63703bec97d23                 NaN          NaN
# 46099  0eb1ee9dba87f5b36b4613a65074337c                 1.0  credit_card
#
#        payment_installments  payment_value
# 18789                   1.0         136.23
# 93479                   3.0          75.06
# 52193                   2.0          40.95
# 77762                   NaN            NaN
# 46099                   1.0         109.34

# %%
payment_log.groupby('order_id').filter(lambda x: len(x) > 2)
# Out:
#                  timestamp                          order_id  \
# 40419  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40421  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40422  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40417  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40416  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# ...                    ...                               ...
# 10502  2018-08-26 22:50:16  19ee088b8cb4afa401a748f8437135d1
# 10501  2018-08-26 22:50:16  19ee088b8cb4afa401a748f8437135d1
# 17798  2018-08-28 15:53:09  2c1f8fd9aa5f50ec17f4c95e52223a3a
# 17800  2018-08-28 15:53:09  2c1f8fd9aa5f50ec17f4c95e52223a3a
# 17799  2018-08-28 15:53:09  2c1f8fd9aa5f50ec17f4c95e52223a3a
#
#                             customer_id  payment_sequential payment_type  \
# 40419  df2988ba3ed226b10521a0e4da849b61                 1.0      voucher
# 40421  df2988ba3ed226b10521a0e4da849b61                 2.0      voucher
# 40422  df2988ba3ed226b10521a0e4da849b61                 3.0      voucher
# 40417  df2988ba3ed226b10521a0e4da849b61                 4.0      voucher
# 40416  df2988ba3ed226b10521a0e4da849b61                 5.0      voucher
# ...                                 ...                 ...          ...
# 10502  b7e8af53ea725e96e5773eb529675c4b                 2.0      voucher
# 10501  b7e8af53ea725e96e5773eb529675c4b                 3.0      voucher
# 17798  bb5d40ed8c3448238563262b4700bae5                 1.0      voucher
# 17800  bb5d40ed8c3448238563262b4700bae5                 2.0      voucher
# 17799  bb5d40ed8c3448238563262b4700bae5                 3.0      voucher
#
#        payment_installments  payment_value
# 40419                   1.0          15.10
# 40421                   1.0          11.99
# 40422                   1.0           9.02
# 40417                   1.0          10.56
# 40416                   1.0          34.19
# ...                     ...            ...
# 10502                   1.0          16.44
# 10501                   1.0          16.12
# 17798                   1.0          20.00
# 17800                   1.0          20.00
# 17799                   1.0          18.36
#
# [2643 rows x 7 columns]

# %%
# Mock Payment Log 생성 및 처리
def create_mock_payment_log(payment_log):
    """
    결제 로그의 mock 데이터를 생성하여 중복 timestamp를 처리합니다.
    
    Args:
        payment_log: 원본 결제 로그 DataFrame
        
    Returns:
        DataFrame: 처리된 mock 결제 로그
    """
    # 1. 원본 데이터 복사 및 기본 전처리
    mock_log = payment_log.copy(deep=True)
    mock_log['timestamp'] = pd.to_datetime(mock_log['timestamp'], errors='coerce')
    
    # 2. 정렬 (timestamp, order_id, payment_sequential 순)
    mock_log = mock_log.sort_values(['timestamp', 'order_id', 'payment_sequential'])
    
    # 3. 중복 timestamp 식별
    mock_log['is_duplicate'] = mock_log.duplicated(subset=['timestamp'], keep=False)
    
    # 4. 중복 timestamp에 랜덤 시간 추가
    mock_log = add_random_time_to_duplicates(mock_log)
    
    return mock_log


def add_random_time_to_duplicates(df):
    """
    중복된 timestamp를 가진 결제에 대해 완료 시각에서 역순으로 랜덤 시간을 차감합니다.
    payment_sequential이 1이 아닌 경우, 가장 마지막 결제 시각에서 20~40초씩 순차 차감합니다.
    
    Args:
        df: 처리할 DataFrame
        
    Returns:
        DataFrame: 조정된 timestamp가 적용된 DataFrame
    """
    # 중복 timestamp 그룹별로 처리
    for timestamp_group in df[df['is_duplicate']]['timestamp'].unique():
        if pd.isna(timestamp_group):
            continue
            
        # 해당 timestamp를 가진 모든 행을 payment_sequential 순으로 정렬
        group_mask = (df['timestamp'] == timestamp_group)
        group_data = df[group_mask].copy()
        group_data = group_data.sort_values('payment_sequential')
        
        # 해당 그룹의 모든 payment_sequential 처리 (1개만 있으면 그대로 유지)
        if len(group_data) > 1:
            # 가장 큰 payment_sequential이 원본 완료 시간 (그대로 유지)
            max_payment_seq = group_data['payment_sequential'].max()
            completion_time = timestamp_group
            
            # payment_sequential을 큰 수부터 작은 수 순으로 정렬
            sorted_payments = group_data.sort_values('payment_sequential', ascending=False)
            
            # 가장 큰 번호를 제외하고 순차적으로 시간 차감
            cumulative_seconds = 0
            for idx, row in sorted_payments.iterrows():
                if row['payment_sequential'] == max_payment_seq:
                    # 가장 큰 payment_sequential은 원본 시간 유지
                    continue
                else:
                    # 20~40초 랜덤 시간 생성 후 누적
                    random_seconds = np.random.uniform(20, 40)
                    cumulative_seconds += random_seconds
                    
                    # 완료 시각에서 누적 시간만큼 차감
                    adjusted_time = completion_time - timedelta(seconds=cumulative_seconds)
                    df.loc[idx, 'timestamp'] = adjusted_time
    
    return df.drop(columns=['is_duplicate'])


# 사용 예시
mock_payment_log = create_mock_payment_log(payment_log)

# %%
mock_payment_log = create_mock_payment_log(payment_log)

# %%
payment_log[payment_log['order_id']=='63638a6806d67773f3adba8534553fff']
# Out:
#                  timestamp                          order_id  \
# 40419  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40421  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40422  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40417  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40416  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40418  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
# 40420  2016-10-04 13:22:56  63638a6806d67773f3adba8534553fff
#
#                             customer_id  payment_sequential payment_type  \
# 40419  df2988ba3ed226b10521a0e4da849b61                 1.0      voucher
# 40421  df2988ba3ed226b10521a0e4da849b61                 2.0      voucher
# 40422  df2988ba3ed226b10521a0e4da849b61                 3.0      voucher
# 40417  df2988ba3ed226b10521a0e4da849b61                 4.0      voucher
# 40416  df2988ba3ed226b10521a0e4da849b61                 5.0      voucher
# 40418  df2988ba3ed226b10521a0e4da849b61                 6.0      voucher
# 40420  df2988ba3ed226b10521a0e4da849b61                 7.0      voucher
#
#        payment_installments  payment_value
# 40419                   1.0          15.10
# 40421                   1.0          11.99
# 40422                   1.0           9.02
# 40417                   1.0          10.56
# 40416                   1.0          34.19
# 40418                   1.0           5.28
# 40420                   1.0           0.74

# %%
mock_payment_log[mock_payment_log['order_id']=='63638a6806d67773f3adba8534553fff']
# Out:
#                        timestamp                          order_id  \
# 40419 2016-10-04 13:19:54.777581  63638a6806d67773f3adba8534553fff
# 40421 2016-10-04 13:20:28.892404  63638a6806d67773f3adba8534553fff
# 40422 2016-10-04 13:21:02.465816  63638a6806d67773f3adba8534553fff
# 40417 2016-10-04 13:21:25.194320  63638a6806d67773f3adba8534553fff
# 40416 2016-10-04 13:22:00.807271  63638a6806d67773f3adba8534553fff
# 40418 2016-10-04 13:22:31.234493  63638a6806d67773f3adba8534553fff
# 40420 2016-10-04 13:22:56.000000  63638a6806d67773f3adba8534553fff
#
#                             customer_id  payment_sequential payment_type  \
# 40419  df2988ba3ed226b10521a0e4da849b61                 1.0      voucher
# 40421  df2988ba3ed226b10521a0e4da849b61                 2.0      voucher
# 40422  df2988ba3ed226b10521a0e4da849b61                 3.0      voucher
# 40417  df2988ba3ed226b10521a0e4da849b61                 4.0      voucher
# 40416  df2988ba3ed226b10521a0e4da849b61                 5.0      voucher
# 40418  df2988ba3ed226b10521a0e4da849b61                 6.0      voucher
# 40420  df2988ba3ed226b10521a0e4da849b61                 7.0      voucher
#
#        payment_installments  payment_value
# 40419                   1.0          15.10
# 40421                   1.0          11.99
# 40422                   1.0           9.02
# 40417                   1.0          10.56
# 40416                   1.0          34.19
# 40418                   1.0           5.28
# 40420                   1.0           0.74

# %%
mock_payment_log.sort_values('timestamp').to_csv(f"{STREAM_DST}/payment_logs.tsv", index=False, sep='\t')
