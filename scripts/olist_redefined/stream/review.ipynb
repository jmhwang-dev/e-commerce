# %%
import pandas as pd
import os

# %%
REDEFINED_DIR = "../../../downloads/olist_redefined"
STREAM_DST = os.path.join(REDEFINED_DIR, 'stream')
BATCH_DST = os.path.join(REDEFINED_DIR, 'batch')
os.makedirs(STREAM_DST, exist_ok=True)
os.makedirs(BATCH_DST, exist_ok=True)

# %% [markdown]
# `review`

# %%
df = pd.read_csv("../../../downloads/olist/olist_order_reviews_dataset.csv")
df.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
df.drop_duplicates().shape == df.shape
# Out:
# True

# %%
df.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
df = df[["review_creation_date", 'review_answer_timestamp', 'review_id', 'order_id', 'review_score', 'review_comment_title',
       'review_comment_message']]

# %%
df.sort_values('review_creation_date').to_csv(f"{STREAM_DST}/review.tsv", index=False, sep='\t')
