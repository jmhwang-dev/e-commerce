# %%
import pandas as pd
import os

# %%
from pathlib import Path

REDEFINED_DIR = "../../downloads/olist_redefined"
os.makedirs(REDEFINED_DIR, exist_ok=True)

# %% [markdown]
# `Orders`

# %%
df = pd.read_csv("../../downloads/olist/olist_orders_dataset.csv")
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %% [markdown]
# ### estimated_delivery

# %%
estimated_delivery = df[['order_estimated_delivery_date', 'order_id',]]
estimated_delivery = estimated_delivery.rename(columns={'order_estimated_delivery_date': 'estimated_delivery_date'})
estimated_delivery = estimated_delivery.sort_values('estimated_delivery_date')
estimated_delivery.to_csv(f"{REDEFINED_DIR}/estimated_delivery_date.tsv", index=False, sep='\t')
