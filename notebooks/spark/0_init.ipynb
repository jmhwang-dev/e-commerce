# %%
from pyspark.sql import functions as F
from service.utils.spark import get_spark_session
spark = get_spark_session(dev=True)

# %%
test_namespace = 'gold' 
# spark.sql(f"DROP NAMESPACE IF EXISTS {test_namespace} CASCADE")
spark.sql(f"CREATE NAMESPACE IF NOT EXISTS {test_namespace}").show()
# Out:
# ++
# ||
# ++
# ++

# %%
# for table in [row.tableName for row in spark.sql('show tables in gold').collect()]:
#     spark.sql(f'drop table if exists gold.{table} purge')
#     spark.sql(f'DESCRIBE FORMATTED gold.{table}').show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for table in [row.tableName for row in spark.sql('show tables in gold').collect()]:
#       2     spark.sql(f'drop table if exists gold.{table} purge')
#       3     spark.sql(f'DESCRIBE FORMATTED gold.{table}').show()
#
# File /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:1262, in DataFrame.collect(self)
#    1242 def collect(self) -> List[Row]:
#    1243     """Returns all the records as a list of :class:`Row`.
#    1244
#    1245     .. versionadded:: 1.3.0
#    (...)
#    1260     [Row(age=14, name='Tom'), Row(age=23, name='Alice'), Row(age=16, name='Bob')]
#    1261     """
# -> 1262     with SCCallSiteSync(self._sc):
#    1263         sock_info = self._jdf.collectToPython()
#    1264     return list(_load_from_socket(sock_info, BatchedSerializer(CPickleSerializer())))
#
# ...

# %%
spark.sql('show tables in silver').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# +---------+---------+-----------+

# %%
spark.stop()
