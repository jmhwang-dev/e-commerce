# %%
import pandas as pd
from src.load_df import *
import duckdb

# %%
save_dir = os.path.join(ARTIFACT_DIR, 'features')
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# ## 배송 지연 일 수

# %%
orders = get_origin_df(OlistFileName.ORDERS)
orders.head(1)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00

# %%
duckdb.query("""
    SELECT order_id FROM tmp_df 
    WHERE order_id LIKE '%481%'
""")
# Out:
# ┌──────────────────────────────────┐
# │             order_id             │
# │             varchar              │
# ├──────────────────────────────────┤
# │ e481f51cbdc54678b7cc49136f2d6af7 │
# │ 47aa4816b27ba60ec948cd019cc1afc1 │
# │ 9defaf92cff22420e4e8ef7784815a55 │
# │ e22b71f6e4a481445ec4527cb4c405f7 │
# │ 66cf92fc3ec94fbafc4edd77e0814818 │
# │ 5a630e3d4aeb6fca86404481eb19cfe7 │
# │ d5211af24819d319c02a285e7bb51750 │
# │ 4dcc01481b7ab4f5f37c8eb4c4c67841 │
# │ 045c9852284420b9c02d156436e1481c │
# │ 68553e9e7b2c06807226ff348142d3ba │
# │                ·                 │
# │                ·                 │
# │                ·                 │
# │ 92d16bd458db6ad7e89154817101087f │
# │ 41481f110ca58f4d3ee2e077d0313ff3 │
# │ a41b4eceec5fb4df1207586f935af481 │
# │ 2911b82b07d1481125508ab8b0292446 │
# │ af4812c0286cb623517321205ffb5d1e │
# │ 2b5bd09c3c5b318e1b7293015fdfb481 │
# │ a0fd703a1c6a122520246bd8d481e528 │
# │ 498bd6074c1c42f8c5bf3481c471c67e │
# │ d81e1aea4814c6e5744458bcd1f94693 │
# │ 3cea94817a51f34aa5937784fb4a3219 │
# ├──────────────────────────────────┤
# │       697 rows (20 shown)        │
# └──────────────────────────────────┘

# %%
duckdb.query("""
    SELECT order_id FROM tmp_df 
    WHERE order_id IN ('481')
""")
# Out:
# ┌──────────┐
# │ order_id │
# │ varchar  │
# ├──────────┤
# │  0 rows  │
# └──────────┘

# %%
keywords = {"time", "timestamp", "date", "at"}

cols_time = [
    col for col in orders.columns
    if any(tok in keywords for tok in col.lower().split("_"))
]
cols_time
# Out:
# ['order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
orders_times = orders[cols_time].apply(
    pd.to_datetime, errors="coerce"
)
orders_times['order_id'] = orders.order_id
orders_times
# Out:
#       order_purchase_timestamp   order_approved_at  \
# 0          2017-10-02 10:56:33 2017-10-02 11:07:15
# 1          2018-07-24 20:41:37 2018-07-26 03:24:27
# 2          2018-08-08 08:38:49 2018-08-08 08:55:23
# 3          2017-11-18 19:28:06 2017-11-18 19:45:59
# 4          2018-02-13 21:18:39 2018-02-13 22:20:29
# ...                        ...                 ...
# 99436      2017-03-09 09:54:05 2017-03-09 09:54:05
# 99437      2018-02-06 12:58:58 2018-02-06 13:10:37
# 99438      2017-08-27 14:46:43 2017-08-27 15:04:16
# 99439      2018-01-08 21:28:27 2018-01-08 21:36:21
# 99440      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                          order_id
# 0                        2017-10-18  e481f51cbdc54678b7cc49136f2d6af7
# 1                        2018-08-13  53cdb2fc8bc7dce0b6741e2150273451
# 2                        2018-09-04  47770eb9100c2d0c44946d9cf07ec65d
# 3                        2017-12-15  949d5b44dbf5de918fe9c16f97b45f8a
# 4                        2018-02-26  ad21c59c0840e6cb83a9ceb5573f8159
# ...                             ...                               ...
# 99436                    2017-03-28  9c5dedf39a927c1b2549525ed64a053c
# 99437                    2018-03-02  63943bddc261676b46f01ca7ac2f7bd8
# 99438                    2017-09-27  83c1379a015df1e13d02aae0204711ab
# 99439                    2018-02-15  11c177c8e97725db2631073c19f07b62
# 99440                    2018-04-03  66dea50a8b16d9b4dee7af250b4be1a5
#
# [99441 rows x 6 columns]

# %%
orders_times["delivery_diff_days"] = orders_times['order_estimated_delivery_date'] - orders_times['order_delivered_customer_date']

# %%
save_path = os.path.join(save_dir, "delivery_diff_days.csv")
orders_times[['order_id', 'delivery_diff_days']].to_csv(save_path)

# %% [markdown]
# ## 배송지연 여부

# %%
# 확인: order_delivered_customer_date가 없는 것도 있음

mask_late = orders_times.delivery_diff_days.dt.total_seconds() < 0
mask_nat  = orders_times.delivery_diff_days.isna()

is_late_delivery = orders_times[mask_late | mask_nat][
    ["order_id", "delivery_diff_days"]
]

save_path = os.path.join(save_dir, "is_late_delivery.csv")
is_late_delivery.to_csv(save_path, index=False)

# %% [markdown]
# ## 주문 별 상품 수

# %%
order_items = get_origin_df(OlistFileName.ORDER_ITEMS)
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
save_path = os.path.join(save_dir, 'order_items_count.csv')
order_items['order_id'].value_counts().to_csv(save_path)

# %% [markdown]
# ## 주문 별 판매자 개수

# %%
save_path = os.path.join(save_dir, "seller_count_by_order.csv")
seller_count_by_order = order_items.groupby('order_id')['seller_id'].nunique()
seller_count_by_order.to_csv(save_path)

# %%
seller_count_by_order[seller_count_by_order > 1]
# Out:
# order_id
# 002f98c0f7efd42638ed6100ca699b42    2
# 00bcee890eba57a9767c7b5ca12d3a1b    2
# 01144cadcf64b6427f0a6580a3033220    2
# 013a98b3a668bcef05b98898177f6923    2
# 014405982914c2cde2796ddcf0b8703d    2
#                                    ..
# feded510efe2a76dd134d8533af626f9    2
# feea1134dca132388da564d8f026a2ca    2
# ff00a56fe9475a175cd651d77c707a09    2
# ff2a353ee8dfd97ba95c73cca4ed2636    2
# ffb8f7de8940249a3221252818937ecb    3
# Name: seller_id, Length: 1278, dtype: int64

# %%
# 확인: 한 주문에 여러 다른 물품 구매
order_items[order_items.order_id == "002f98c0f7efd42638ed6100ca699b42"]
# Out:
#                             order_id  order_item_id  \
# 80  002f98c0f7efd42638ed6100ca699b42              1
# 81  002f98c0f7efd42638ed6100ca699b42              2
#
#                           product_id                         seller_id  \
# 80  d41dc2f2979f52d75d78714b378d4068  7299e27ed73d2ad986de7f7c77d919fa
# 81  880be32f4db1d9f6e2bec38fb6ac23ab  fa40cc5b934574b62717c68f3d678b6d
#
#     shipping_limit_date  price  freight_value
# 80  2017-08-10 09:30:15   8.99          32.57
# 81  2017-08-10 09:30:15  44.90           7.16

# %% [markdown]
# ## 거리 및 지역 정보

# %%
customers = get_origin_df(OlistFileName.CUSTOMERS)
sellers = get_origin_df(OlistFileName.SELLERS)
geolocation = get_preprocessed_df(OlistFileName.GEOLOCATION)

geolocation.shape
# Out:
# (19023, 5)

# %%
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 4 columns]

# %%
seller_location = pd.merge(sellers[['seller_id', 'seller_zip_code_prefix']], geolocation[['geolocation_zip_code_prefix', 'geolocation_lat','geolocation_lng']], left_on='seller_zip_code_prefix', right_on="geolocation_zip_code_prefix", how='left')
seller_location.drop_duplicates(inplace=True)
seller_location.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                      13023.0       -22.893317       -47.060596
# 1                      13844.0       -22.383375       -46.948142
# 2                      20031.0       -22.909446       -43.180240
# 3                       4195.0       -23.657118       -46.612730
# 4                      12914.0       -22.964546       -46.534214

# %%
customer_location = pd.merge(customers[['customer_id', 'customer_zip_code_prefix']], geolocation[['geolocation_zip_code_prefix', 'geolocation_lat','geolocation_lng']], left_on='customer_zip_code_prefix', right_on="geolocation_zip_code_prefix", how='left')
customer_location.drop_duplicates(inplace=True)
customer_location.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1  18955e83d337fd6b2def6b18a428ac77                      9790
# 2  4e7b3e00288586ebd08712fdd0374a03                      1151
# 3  b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4  4f2d8ab171c80ec8364f7c12e35b23ad                     13056
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                      14409.0       -20.499273       -47.396658
# 1                       9790.0       -23.728396       -46.542250
# 2                       1151.0       -23.531309       -46.656690
# 3                       8775.0       -23.500670       -46.186348
# 4                      13056.0       -22.975708       -47.143140

# %%
order_items = get_origin_df(OlistFileName.ORDER_ITEMS)
orders = get_origin_df(OlistFileName.ORDERS)

# %%
joined_customer_seller_order = pd.merge(orders[['order_id', 'customer_id']], order_items[['order_id', 'seller_id']], on='order_id', how='left' )
joined_customer_seller_order
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#                                seller_id
# 0       3504c0cb71d7fa48d967e0e4c94d59d9
# 1       289cdb325fb7e7f891c38608bf9e0962
# 2       4869f7a5dfa277a7dca6462dcf3b52b2
# 3       66922902710d126a0e7d26b0e3805106
# 4       2c9e548be18521d1c43cde1c582c6de8
# ...                                  ...
# 113420  1f9ab4708f3056ede07124aad39a2554
# 113421  d50d79cb34e38265a8649c383dcffd48
# 113422  a1043bafd471dff536d0c462352beb48
# 113423  a1043bafd471dff536d0c462352beb48
# 113424  ececbfcff9804a2d6b40f589df8eef2b
#
# [113425 rows x 3 columns]

# %%
locations = pd.merge(joined_customer_seller_order, customer_location[['customer_id', 'geolocation_lat','geolocation_lng']], on='customer_id', how='left')
locations = pd.merge(locations, seller_location[['seller_id', 'geolocation_lat','geolocation_lng']], on='seller_id', how='left', suffixes=['_customer', '_seller'])
locations.drop_duplicates(inplace=True)
locations.shape
# Out:
# (100785, 7)

# %%
locations
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113419  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#                                seller_id  geolocation_lat_customer  \
# 0       3504c0cb71d7fa48d967e0e4c94d59d9                -23.577482
# 1       289cdb325fb7e7f891c38608bf9e0962                -12.186877
# 2       4869f7a5dfa277a7dca6462dcf3b52b2                -16.745150
# 3       66922902710d126a0e7d26b0e3805106                 -5.774002
# 4       2c9e548be18521d1c43cde1c582c6de8                -23.676257
# ...                                  ...                       ...
# 113419  e24fc9fcd865784fb25705606fe3dfe7                -23.177943
# 113420  1f9ab4708f3056ede07124aad39a2554                -24.001334
# 113421  d50d79cb34e38265a8649c383dcffd48                -17.898045
# 113422  a1043bafd471dff536d0c462352beb48                -22.563909
# 113424  ececbfcff9804a2d6b40f589df8eef2b                -25.764399
#
#         geolocation_lng_customer  geolocation_lat_seller  \
# 0                     -46.587077              -23.680862
# 1                     -44.540232              -19.807885
# 2                     -48.514783              -21.363473
# 3                     -35.270976              -19.836871
# 4                     -46.514580              -23.541525
# ...                          ...                     ...
# 113419                -45.882139              -22.960926
# 113420                -46.450022              -21.930464
# 113421                -39.373106              -23.553949
# 113422                -42.695343              -20.940712
# 113424                -49.719699              -20.496403
#
#         geolocation_lng_seller
# 0                   -46.444311
# 1                   -43.980818
# 2                   -48.229588
# 3                   -43.923241
# 4                   -46.262148
# ...                        ...
# 113419              -46.524336
# 113420              -50.498065
# 113421              -46.453257
# 113422              -45.827195
# 113424              -47.418012
#
# [100785 rows x 7 columns]
