# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('dbt_test').getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/07/11 15:21:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/07/11 15:21:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark.sql("SHOW TABLES IN warehouse_dev.gold").show(truncate=False)
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |gold     |is_late  |false      |
# +---------+---------+-----------+

# %%
df = spark.table("warehouse_dev.gold.is_late")
df.show()
# Out:
# +--------------------+--------------------+-------+
# |            order_id|         customer_id|is_late|
# +--------------------+--------------------+-------+
# |acce194856392f074...|7e20bf5ca92da6820...|  false|
# |1d067305b599c1e0d...|0489975a325480c9e...|  false|
# |6f841dde94727854e...|a9c9532060c9d245f...|  false|
# |ca290a06ee0945b95...|acd575d7382968889...|  false|
# |3735720b8c1cd4212...|94af59d9cac1ae197...|  false|
# |8b346abc34a6e64bc...|dd1506d329d9b0135...|  false|
# |a4d7c8bca45b56444...|fcdb673d0f8d2b84d...|  false|
# |b64b1539563ff5159...|a22203b8cd7210764...|  false|
# |e05ad3bb40dd7a1f0...|348dab3f7710f2be3...|  false|
# |0c00bf3feaaced2a1...|a4f809d1f8681ff7b...|  false|
# |69b4682d3ab5ef1f1...|765b56e9a7716dfe3...|  false|
# |f222c56f035b47dfa...|b74ca180d63f9ae04...|  false|
# |341dc4ea81fabe7de...|8a8c2e93d6ec33bb9...|  false|
# |3f71c7ea78bd7df67...|69a5de2d98d4729f8...|  false|
# |82fa967d1d3bc56f3...|4d36af0b2f66083f2...|  false|
# ...
